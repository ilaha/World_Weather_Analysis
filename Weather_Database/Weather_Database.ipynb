# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import time module
import time
# Import dependencies
from scipy.stats import linregress

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        time.sleep(1)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 1 | salina
# Processing Record 7 of Set 1 | grand gaube
# Processing Record 8 of Set 1 | kruisfontein
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | olafsvik
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | sitka
# Processing Record 13 of Set 1 | pangoa
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | tecoanapa
# Processing Record 18 of Set 1 | yarada
# Processing Record 19 of Set 1 | aklavik
# Processing Record 20 of Set 1 | bosaso
# Processing Record 21 of Set 1 | griffith
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | pisco
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | svetlogorsk
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | sal rei
# Processing Record 29 of Set 1 | lushunkou
# City not found. Skipping...
# Processing Record 30 of Set 1 | bathsheba
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 1 | balingasay
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | xining
# Processing Record 39 of Set 1 | geraldton
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | graaff-reinet
# Processing Record 42 of Set 1 | yeppoon
# Processing Record 43 of Set 1 | marsh harbour
# Processing Record 44 of Set 1 | ancud
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | bronnoysund
# Processing Record 47 of Set 1 | sambalpur
# Processing Record 48 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | hambantota
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | leningradskiy
# Processing Record 6 of Set 2 | yulara
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | gilgit
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | richards bay
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | rikitea
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | nantucket
# Processing Record 21 of Set 2 | lata
# Processing Record 22 of Set 2 | orasac
# Processing Record 23 of Set 2 | north battleford
# Processing Record 24 of Set 2 | tiruvottiyur
# City not found. Skipping...
# Processing Record 25 of Set 2 | kargasok
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | namibe
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | constitucion
# Processing Record 30 of Set 2 | arraial do cabo
# Processing Record 31 of Set 2 | belyy yar
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | naze
# Processing Record 34 of Set 2 | oranjestad
# Processing Record 35 of Set 2 | coihaique
# Processing Record 36 of Set 2 | binzhou
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | ugoofaaru
# Processing Record 39 of Set 2 | maku
# Processing Record 40 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 2 | mastic beach
# Processing Record 42 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 2 | banposh
# Processing Record 44 of Set 2 | provideniya
# Processing Record 45 of Set 2 | menongue
# Processing Record 46 of Set 2 | paamiut
# Processing Record 47 of Set 2 | dutlwe
# Processing Record 48 of Set 2 | coquimbo
# Processing Record 49 of Set 2 | roma
# Processing Record 50 of Set 2 | kozlovo
# Processing Record 1 of Set 3 | plouzane
# Processing Record 2 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 3 | miandrivazo
# Processing Record 4 of Set 3 | alice springs
# Processing Record 5 of Set 3 | khashuri
# Processing Record 6 of Set 3 | mayo
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | chuncheng
# Processing Record 9 of Set 3 | les cayes
# Processing Record 10 of Set 3 | upata
# Processing Record 11 of Set 3 | mandalgovi
# Processing Record 12 of Set 3 | zverinogolovskoye
# Processing Record 13 of Set 3 | pacific grove
# Processing Record 14 of Set 3 | merrill
# Processing Record 15 of Set 3 | aranos
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | lorengau
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | atbasar
# Processing Record 21 of Set 3 | faanui
# Processing Record 22 of Set 3 | xai-xai
# Processing Record 23 of Set 3 | souillac
# Processing Record 24 of Set 3 | alexandria
# Processing Record 25 of Set 3 | chapleau
# Processing Record 26 of Set 3 | itoman
# Processing Record 27 of Set 3 | clyde river
# Processing Record 28 of Set 3 | bilma
# Processing Record 29 of Set 3 | nouadhibou
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | ca mau
# Processing Record 32 of Set 3 | vila velha
# Processing Record 33 of Set 3 | kupang
# Processing Record 34 of Set 3 | baishishan
# Processing Record 35 of Set 3 | nioro
# Processing Record 36 of Set 3 | rio gallegos
# Processing Record 37 of Set 3 | nieuwpoort
# Processing Record 38 of Set 3 | osakarovka
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | killybegs
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | inongo
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | pevek
# Processing Record 45 of Set 3 | key west
# Processing Record 46 of Set 3 | san lorenzo
# Processing Record 47 of Set 3 | nuuk
# Processing Record 48 of Set 3 | codrington
# Processing Record 49 of Set 3 | williston
# Processing Record 50 of Set 3 | alofi
# Processing Record 1 of Set 4 | oktyabrskoye
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | santa fe
# Processing Record 4 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | najran
# Processing Record 7 of Set 4 | alihe
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | atar
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | marfino
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | yatou
# Processing Record 14 of Set 4 | hobyo
# Processing Record 15 of Set 4 | umm lajj
# Processing Record 16 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 4 | port hardy
# Processing Record 19 of Set 4 | christchurch
# Processing Record 20 of Set 4 | tuatapere
# Processing Record 21 of Set 4 | oranjemund
# Processing Record 22 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 4 | dunedin
# Processing Record 24 of Set 4 | belawan
# Processing Record 25 of Set 4 | cairns
# Processing Record 26 of Set 4 | yelizovo
# Processing Record 27 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 4 | vao
# Processing Record 29 of Set 4 | gabu
# Processing Record 30 of Set 4 | chuy
# Processing Record 31 of Set 4 | kavieng
# Processing Record 32 of Set 4 | marsa matruh
# Processing Record 33 of Set 4 | khatanga
# Processing Record 34 of Set 4 | lasa
# Processing Record 35 of Set 4 | peniche
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | necochea
# Processing Record 38 of Set 4 | cabo san lucas
# Processing Record 39 of Set 4 | tuktoyaktuk
# Processing Record 40 of Set 4 | bluff
# Processing Record 41 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 42 of Set 4 | port lincoln
# Processing Record 43 of Set 4 | oktyabrskiy
# Processing Record 44 of Set 4 | goderich
# Processing Record 45 of Set 4 | siderno
# Processing Record 46 of Set 4 | okhotsk
# Processing Record 47 of Set 4 | tazovskiy
# Processing Record 48 of Set 4 | ostrovnoy
# Processing Record 49 of Set 4 | cidreira
# Processing Record 50 of Set 4 | berck
# Processing Record 1 of Set 5 | bull savanna
# Processing Record 2 of Set 5 | avera
# Processing Record 3 of Set 5 | youghal
# Processing Record 4 of Set 5 | kodinsk
# Processing Record 5 of Set 5 | imbituba
# Processing Record 6 of Set 5 | marawi
# Processing Record 7 of Set 5 | narsaq
# Processing Record 8 of Set 5 | yar-sale
# Processing Record 9 of Set 5 | husavik
# Processing Record 10 of Set 5 | kirakira
# Processing Record 11 of Set 5 | bereda
# Processing Record 12 of Set 5 | hobart
# Processing Record 13 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 5 | cervo
# Processing Record 15 of Set 5 | north platte
# Processing Record 16 of Set 5 | hervey bay
# Processing Record 17 of Set 5 | shorapani
# Processing Record 18 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | safaga
# Processing Record 21 of Set 5 | king city
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | selizharovo
# Processing Record 24 of Set 5 | alghero
# Processing Record 25 of Set 5 | seydi
# Processing Record 26 of Set 5 | esna
# Processing Record 27 of Set 5 | touros
# Processing Record 28 of Set 5 | hofn
# Processing Record 29 of Set 5 | xuddur
# Processing Record 30 of Set 5 | vanimo
# Processing Record 31 of Set 5 | dayong
# Processing Record 32 of Set 5 | lodja
# Processing Record 33 of Set 5 | auki
# Processing Record 34 of Set 5 | dingle
# Processing Record 35 of Set 5 | sokoni
# Processing Record 36 of Set 5 | vila franca do campo
# Processing Record 37 of Set 5 | georgetown
# Processing Record 38 of Set 5 | soria
# Processing Record 39 of Set 5 | doka
# Processing Record 40 of Set 5 | yelatma
# Processing Record 41 of Set 5 | xiaoweizhai
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | lavrentiya
# Processing Record 44 of Set 5 | diffa
# Processing Record 45 of Set 5 | kiunga
# Processing Record 46 of Set 5 | mungwi
# Processing Record 47 of Set 5 | komsomolskiy
# Processing Record 48 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 5 | biltine
# Processing Record 50 of Set 5 | indi
# Processing Record 1 of Set 6 | mahebourg
# Processing Record 2 of Set 6 | lazaro cardenas
# Processing Record 3 of Set 6 | mamakan
# Processing Record 4 of Set 6 | semnan
# Processing Record 5 of Set 6 | cassilandia
# Processing Record 6 of Set 6 | hasaki
# Processing Record 7 of Set 6 | luderitz
# Processing Record 8 of Set 6 | hamilton
# Processing Record 9 of Set 6 | ulaangom
# Processing Record 10 of Set 6 | mapimi
# Processing Record 11 of Set 6 | micheweni
# Processing Record 12 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 6 | vangaindrano
# Processing Record 14 of Set 6 | sokolka
# Processing Record 15 of Set 6 | gondar
# Processing Record 16 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 6 | atenas de san cristobal
# Processing Record 18 of Set 6 | carnarvon
# Processing Record 19 of Set 6 | upernavik
# Processing Record 20 of Set 6 | fairbanks
# Processing Record 21 of Set 6 | neyshabur
# Processing Record 22 of Set 6 | brae
# Processing Record 23 of Set 6 | jaciara
# Processing Record 24 of Set 6 | walvis bay
# Processing Record 25 of Set 6 | meulaboh
# Processing Record 26 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 27 of Set 6 | broome
# Processing Record 28 of Set 6 | shimoda
# Processing Record 29 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 6 | viedma
# Processing Record 31 of Set 6 | constantine
# Processing Record 32 of Set 6 | sao filipe
# Processing Record 33 of Set 6 | kathu
# Processing Record 34 of Set 6 | lamar
# Processing Record 35 of Set 6 | pontes e lacerda
# Processing Record 36 of Set 6 | praia da vitoria
# Processing Record 37 of Set 6 | morehead
# Processing Record 38 of Set 6 | mesyagutovo
# Processing Record 39 of Set 6 | asau
# Processing Record 40 of Set 6 | santa cruz verapaz
# Processing Record 41 of Set 6 | chapais
# Processing Record 42 of Set 6 | sibolga
# Processing Record 43 of Set 6 | puerto ayora
# Processing Record 44 of Set 6 | mopipi
# Processing Record 45 of Set 6 | berlevag
# Processing Record 46 of Set 6 | tabas
# Processing Record 47 of Set 6 | kaeo
# Processing Record 48 of Set 6 | saint george
# Processing Record 49 of Set 6 | jalu
# Processing Record 50 of Set 6 | humberto de campos
# Processing Record 1 of Set 7 | yumen
# Processing Record 2 of Set 7 | bell ville
# Processing Record 3 of Set 7 | sao felix do xingu
# Processing Record 4 of Set 7 | palu
# Processing Record 5 of Set 7 | seoul
# Processing Record 6 of Set 7 | korla
# Processing Record 7 of Set 7 | lieksa
# Processing Record 8 of Set 7 | cap malheureux
# Processing Record 9 of Set 7 | homer
# Processing Record 10 of Set 7 | biak
# Processing Record 11 of Set 7 | general roca
# Processing Record 12 of Set 7 | parrita
# Processing Record 13 of Set 7 | kavaratti
# Processing Record 14 of Set 7 | porto novo
# Processing Record 15 of Set 7 | morondava
# Processing Record 16 of Set 7 | artesia
# Processing Record 17 of Set 7 | bilibino
# Processing Record 18 of Set 7 | sola
# Processing Record 19 of Set 7 | aksarka
# Processing Record 20 of Set 7 | xiazhen
# Processing Record 21 of Set 7 | melaka
# Processing Record 22 of Set 7 | freeport
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | betafo
# Processing Record 25 of Set 7 | salalah
# Processing Record 26 of Set 7 | gamboula
# Processing Record 27 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 7 | combs-la-ville
# Processing Record 29 of Set 7 | mount isa
# Processing Record 30 of Set 7 | glasgow
# Processing Record 31 of Set 7 | iskateley
# Processing Record 32 of Set 7 | mareeba
# Processing Record 33 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 7 | calvinia
# Processing Record 35 of Set 7 | hohhot
# Processing Record 36 of Set 7 | belize
# Processing Record 37 of Set 7 | coahuayana
# Processing Record 38 of Set 7 | vaxjo
# Processing Record 39 of Set 7 | udachnyy
# Processing Record 40 of Set 7 | kodiak
# Processing Record 41 of Set 7 | darnah
# Processing Record 42 of Set 7 | cariati
# Processing Record 43 of Set 7 | keetmanshoop
# Processing Record 44 of Set 7 | kulu
# Processing Record 45 of Set 7 | talnakh
# Processing Record 46 of Set 7 | ust-tsilma
# Processing Record 47 of Set 7 | pelym
# Processing Record 48 of Set 7 | nabire
# Processing Record 49 of Set 7 | puerto colombia
# Processing Record 50 of Set 7 | yacuiba
# Processing Record 1 of Set 8 | karratha
# Processing Record 2 of Set 8 | deputatskiy
# Processing Record 3 of Set 8 | pacifica
# Processing Record 4 of Set 8 | ilulissat
# Processing Record 5 of Set 8 | quatre cocos
# Processing Record 6 of Set 8 | tura
# Processing Record 7 of Set 8 | san juan
# Processing Record 8 of Set 8 | brenham
# Processing Record 9 of Set 8 | banjar
# Processing Record 10 of Set 8 | marrakesh
# Processing Record 11 of Set 8 | chazuta
# Processing Record 12 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 8 | dolgoderevenskoye
# Processing Record 14 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 8 | tiksi
# Processing Record 16 of Set 8 | san andres
# Processing Record 17 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 8 | lahij
# Processing Record 19 of Set 8 | soure
# Processing Record 20 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 21 of Set 8 | copiapo
# Processing Record 22 of Set 8 | san patricio
# Processing Record 23 of Set 8 | wamba
# Processing Record 24 of Set 8 | angoche
# Processing Record 25 of Set 8 | xichang
# Processing Record 26 of Set 8 | birjand
# Processing Record 27 of Set 8 | frankfurt
# Processing Record 28 of Set 8 | dahuk
# Processing Record 29 of Set 8 | shanting
# Processing Record 30 of Set 8 | sao miguel do araguaia
# Processing Record 31 of Set 8 | kautokeino
# Processing Record 32 of Set 8 | ellinikon
# City not found. Skipping...
# Processing Record 33 of Set 8 | anadyr
# Processing Record 34 of Set 8 | mecca
# Processing Record 35 of Set 8 | bakchar
# Processing Record 36 of Set 8 | torbay
# Processing Record 37 of Set 8 | duldurga
# Processing Record 38 of Set 8 | qaqortoq
# Processing Record 39 of Set 8 | hildburghausen
# Processing Record 40 of Set 8 | ozernovskiy
# Processing Record 41 of Set 8 | salcedo
# Processing Record 42 of Set 8 | wagar
# Processing Record 43 of Set 8 | iberia
# Processing Record 44 of Set 8 | chumikan
# Processing Record 45 of Set 8 | bousso
# Processing Record 46 of Set 8 | high level
# Processing Record 47 of Set 8 | mogadishu
# Processing Record 48 of Set 8 | muros
# Processing Record 49 of Set 8 | makakilo city
# Processing Record 50 of Set 8 | ayan
# Processing Record 1 of Set 9 | almondbank
# Processing Record 2 of Set 9 | port blair
# Processing Record 3 of Set 9 | novikovo
# Processing Record 4 of Set 9 | pochutla
# Processing Record 5 of Set 9 | kimbe
# Processing Record 6 of Set 9 | laguna
# Processing Record 7 of Set 9 | borogontsy
# Processing Record 8 of Set 9 | los angeles
# Processing Record 9 of Set 9 | progreso
# Processing Record 10 of Set 9 | kokkola
# Processing Record 11 of Set 9 | corinto
# Processing Record 12 of Set 9 | taldan
# Processing Record 13 of Set 9 | heihe
# Processing Record 14 of Set 9 | lingdong
# Processing Record 15 of Set 9 | bandarbeyla
# Processing Record 16 of Set 9 | butterworth
# Processing Record 17 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 18 of Set 9 | pindushi
# Processing Record 19 of Set 9 | singarayakonda
# Processing Record 20 of Set 9 | tornio
# Processing Record 21 of Set 9 | kosjeric
# Processing Record 22 of Set 9 | clonakilty
# Processing Record 23 of Set 9 | maroantsetra
# Processing Record 24 of Set 9 | san quintin
# Processing Record 25 of Set 9 | krzeszowice
# Processing Record 26 of Set 9 | margate
# Processing Record 27 of Set 9 | thap than
# Processing Record 28 of Set 9 | waipawa
# Processing Record 29 of Set 9 | gualaceo
# Processing Record 30 of Set 9 | lastoursville
# Processing Record 31 of Set 9 | kushmurun
# Processing Record 32 of Set 9 | cherskiy
# Processing Record 33 of Set 9 | pucallpa
# Processing Record 34 of Set 9 | eravur
# Processing Record 35 of Set 9 | sliven
# Processing Record 36 of Set 9 | machinga
# Processing Record 37 of Set 9 | acarau
# Processing Record 38 of Set 9 | noumea
# Processing Record 39 of Set 9 | tiznit
# Processing Record 40 of Set 9 | anito
# Processing Record 41 of Set 9 | lamu
# Processing Record 42 of Set 9 | palanga
# Processing Record 43 of Set 9 | bambanglipuro
# Processing Record 44 of Set 9 | pemangkat
# Processing Record 45 of Set 9 | lagoa
# Processing Record 46 of Set 9 | manakara
# Processing Record 47 of Set 9 | yaan
# Processing Record 48 of Set 9 | isangel
# Processing Record 49 of Set 9 | nhulunbuy
# Processing Record 50 of Set 9 | surt
# Processing Record 1 of Set 10 | kangaatsiaq
# Processing Record 2 of Set 10 | taoudenni
# Processing Record 3 of Set 10 | buin
# Processing Record 4 of Set 10 | kang
# Processing Record 5 of Set 10 | klyuchi
# Processing Record 6 of Set 10 | sobolevo
# Processing Record 7 of Set 10 | andapa
# Processing Record 8 of Set 10 | burnie
# Processing Record 9 of Set 10 | cajamarca
# Processing Record 10 of Set 10 | yertarskiy
# Processing Record 11 of Set 10 | comodoro rivadavia
# Processing Record 12 of Set 10 | katsuura
# Processing Record 13 of Set 10 | jumla
# Processing Record 14 of Set 10 | ouadda
# Processing Record 15 of Set 10 | lompoc
# Processing Record 16 of Set 10 | guerrero negro
# Processing Record 17 of Set 10 | gunnedah
# Processing Record 18 of Set 10 | videira
# Processing Record 19 of Set 10 | omboue
# Processing Record 20 of Set 10 | svarstad
# Processing Record 21 of Set 10 | sambava
# Processing Record 22 of Set 10 | tilichiki
# Processing Record 23 of Set 10 | killarney
# Processing Record 24 of Set 10 | elat
# Processing Record 25 of Set 10 | duz
# City not found. Skipping...
# Processing Record 26 of Set 10 | punta gorda
# Processing Record 27 of Set 10 | leon
# Processing Record 28 of Set 10 | sredec
# City not found. Skipping...
# Processing Record 29 of Set 10 | saint-joseph
# Processing Record 30 of Set 10 | saldanha
# Processing Record 31 of Set 10 | kharp
# Processing Record 32 of Set 10 | ketchikan
# Processing Record 33 of Set 10 | verkhnetulomskiy
# Processing Record 34 of Set 10 | leh
# Processing Record 35 of Set 10 | palmer
# Processing Record 36 of Set 10 | half moon bay
# Processing Record 37 of Set 10 | akyab
# Processing Record 38 of Set 10 | kochubey
# Processing Record 39 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 10 | podor
# Processing Record 41 of Set 10 | ahar
# Processing Record 42 of Set 10 | taunggyi
# Processing Record 43 of Set 10 | biskamzha
# Processing Record 44 of Set 10 | henties bay
# Processing Record 45 of Set 10 | preobrazheniye
# Processing Record 46 of Set 10 | yellapur
# Processing Record 47 of Set 10 | sao raimundo nonato
# Processing Record 48 of Set 10 | bambous virieux
# Processing Record 49 of Set 10 | matay
# Processing Record 50 of Set 10 | zabol
# Processing Record 1 of Set 11 | broken hill
# Processing Record 2 of Set 11 | sisimiut
# Processing Record 3 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 4 of Set 11 | neiafu
# Processing Record 5 of Set 11 | kwekwe
# Processing Record 6 of Set 11 | ngaoundere
# Processing Record 7 of Set 11 | mbandaka
# Processing Record 8 of Set 11 | placido de castro
# Processing Record 9 of Set 11 | loandjili
# Processing Record 10 of Set 11 | venice
# Processing Record 11 of Set 11 | kralendijk
# Processing Record 12 of Set 11 | hoi an
# Processing Record 13 of Set 11 | mizdah
# Processing Record 14 of Set 11 | ajaccio
# Processing Record 15 of Set 11 | maniago
# Processing Record 16 of Set 11 | hami
# Processing Record 17 of Set 11 | timiryazevskoye
# Processing Record 18 of Set 11 | barcelos
# Processing Record 19 of Set 11 | golden
# Processing Record 20 of Set 11 | port hedland
# Processing Record 21 of Set 11 | hay river
# Processing Record 22 of Set 11 | vostok
# Processing Record 23 of Set 11 | joensuu
# Processing Record 24 of Set 11 | huron
# Processing Record 25 of Set 11 | nyuksenitsa
# Processing Record 26 of Set 11 | kysyl-syr
# Processing Record 27 of Set 11 | ranong
# Processing Record 28 of Set 11 | dire
# Processing Record 29 of Set 11 | mackay
# Processing Record 30 of Set 11 | bin qirdan
# Processing Record 31 of Set 11 | gloucester
# Processing Record 32 of Set 11 | athabasca
# Processing Record 33 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 11 | nishihara
# Processing Record 35 of Set 11 | la ceiba
# Processing Record 36 of Set 11 | baculin
# Processing Record 37 of Set 11 | jiangkou
# Processing Record 38 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 39 of Set 11 | aktau
# Processing Record 40 of Set 11 | the valley
# Processing Record 41 of Set 11 | hualmay
# Processing Record 42 of Set 11 | komatipoort
# Processing Record 43 of Set 11 | axim
# Processing Record 44 of Set 11 | byumba
# Processing Record 45 of Set 11 | astara
# Processing Record 46 of Set 11 | ituiutaba
# Processing Record 47 of Set 11 | chegdomyn
# Processing Record 48 of Set 11 | hit
# Processing Record 49 of Set 11 | loreto
# Processing Record 50 of Set 11 | bayan
# Processing Record 1 of Set 12 | ulsteinvik
# Processing Record 2 of Set 12 | gwadar
# Processing Record 3 of Set 12 | richard toll
# City not found. Skipping...
# Processing Record 4 of Set 12 | ballina
# Processing Record 5 of Set 12 | arman
# Processing Record 6 of Set 12 | oistins
# Processing Record 7 of Set 12 | inirida
# Processing Record 8 of Set 12 | slave lake
# Processing Record 9 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 12 | poya
# Processing Record 11 of Set 12 | bay roberts
# Processing Record 12 of Set 12 | wodonga
# Processing Record 13 of Set 12 | daru
# Processing Record 14 of Set 12 | cascais
# Processing Record 15 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 12 | mayskiy
# Processing Record 17 of Set 12 | aquiraz
# Processing Record 18 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 12 | neryungri
# Processing Record 20 of Set 12 | chirongui
# Processing Record 21 of Set 12 | cheremkhovo
# Processing Record 22 of Set 12 | brandon
# Processing Record 23 of Set 12 | turkan
# Processing Record 24 of Set 12 | westport
# Processing Record 25 of Set 12 | honiara
# Processing Record 26 of Set 12 | mudanjiang
# Processing Record 27 of Set 12 | hirara
# Processing Record 28 of Set 12 | las palmas
# Processing Record 29 of Set 12 | lethem
# Processing Record 30 of Set 12 | ikalamavony
# Processing Record 31 of Set 12 | pitimbu
# Processing Record 32 of Set 12 | celestun
# Processing Record 33 of Set 12 | iracoubo
# Processing Record 34 of Set 12 | conceicao do araguaia
# Processing Record 35 of Set 12 | ximei
# Processing Record 36 of Set 12 | sao joao da barra
# Processing Record 37 of Set 12 | synya
# Processing Record 38 of Set 12 | batagay-alyta
# Processing Record 39 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 40 of Set 12 | yelan
# Processing Record 41 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 42 of Set 12 | aswan
# Processing Record 43 of Set 12 | venado tuerto
# Processing Record 44 of Set 12 | tatawin
# Processing Record 45 of Set 12 | basco
# Processing Record 46 of Set 12 | kem
# Processing Record 47 of Set 12 | rio grande
# Processing Record 48 of Set 12 | goure
# Processing Record 49 of Set 12 | diamantino
# Processing Record 50 of Set 12 | vestmannaeyjar
# Processing Record 1 of Set 13 | roura
# Processing Record 2 of Set 13 | inuvik
# Processing Record 3 of Set 13 | grindavik
# Processing Record 4 of Set 13 | ampanihy
# Processing Record 5 of Set 13 | sernur
# Processing Record 6 of Set 13 | khomeynishahr
# City not found. Skipping...
# Processing Record 7 of Set 13 | batagay
# Processing Record 8 of Set 13 | azovo
# Processing Record 9 of Set 13 | maldonado
# Processing Record 10 of Set 13 | volchansk
# Processing Record 11 of Set 13 | torbat-e jam
# Processing Record 12 of Set 13 | uglegorsk
# Processing Record 13 of Set 13 | yibin
# Processing Record 14 of Set 13 | stekolnyy
# City not found. Skipping...
# Processing Record 15 of Set 13 | svetlyy
# Processing Record 16 of Set 13 | balakovo
# Processing Record 17 of Set 13 | praya
# Processing Record 18 of Set 13 | whitehorse
# Processing Record 19 of Set 13 | areosa
# Processing Record 20 of Set 13 | mizan teferi
# Processing Record 21 of Set 13 | chifeng
# Processing Record 22 of Set 13 | jieshi
# Processing Record 23 of Set 13 | zyryanka
# Processing Record 24 of Set 13 | mitsamiouli
# Processing Record 25 of Set 13 | awbari
# Processing Record 26 of Set 13 | labytnangi
# Processing Record 27 of Set 13 | seguin
# Processing Record 28 of Set 13 | adrar
# Processing Record 29 of Set 13 | halifax
# Processing Record 30 of Set 13 | concordia
# Processing Record 31 of Set 13 | edd
# Processing Record 32 of Set 13 | zhenlai
# Processing Record 33 of Set 13 | athmallik
# Processing Record 34 of Set 13 | vanderhoof
# Processing Record 35 of Set 13 | meadow lake
# Processing Record 36 of Set 13 | raga
# Processing Record 37 of Set 13 | capim grosso
# Processing Record 38 of Set 13 | cocobeach
# Processing Record 39 of Set 13 | camargo
# Processing Record 40 of Set 13 | pa sang
# Processing Record 41 of Set 13 | ust-omchug
# Processing Record 42 of Set 13 | nemuro
# Processing Record 43 of Set 13 | senanga
# Processing Record 44 of Set 13 | effingham
# Processing Record 45 of Set 13 | tikapur
# Processing Record 46 of Set 13 | nehe
# Processing Record 47 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 48 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 13 | igrim
# Processing Record 50 of Set 13 | ayagoz
# Processing Record 1 of Set 14 | znamensk
# Processing Record 2 of Set 14 | carauari
# Processing Record 3 of Set 14 | la puebla de cazalla
# Processing Record 4 of Set 14 | forest grove
# Processing Record 5 of Set 14 | tarakan
# Processing Record 6 of Set 14 | juneau
# Processing Record 7 of Set 14 | callaway
# Processing Record 8 of Set 14 | cockburn town
# Processing Record 9 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 10 of Set 14 | virginia beach
# Processing Record 11 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 14 | la crosse
# Processing Record 13 of Set 14 | arosa
# Processing Record 14 of Set 14 | caucaia
# Processing Record 15 of Set 14 | umm kaddadah
# Processing Record 16 of Set 14 | wanning
# Processing Record 17 of Set 14 | kyra
# Processing Record 18 of Set 14 | mabaruma
# Processing Record 19 of Set 14 | ahipara
# Processing Record 20 of Set 14 | sinnar
# Processing Record 21 of Set 14 | tahe
# Processing Record 22 of Set 14 | tommot
# Processing Record 23 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 24 of Set 14 | orange
# Processing Record 25 of Set 14 | kloulklubed
# Processing Record 26 of Set 14 | lakes entrance
# Processing Record 27 of Set 14 | abu samrah
# Processing Record 28 of Set 14 | pringsewu
# Processing Record 29 of Set 14 | srednekolymsk
# Processing Record 30 of Set 14 | filadelfia
# Processing Record 31 of Set 14 | jiayuguan
# Processing Record 32 of Set 14 | srbac
# Processing Record 33 of Set 14 | chateauroux
# Processing Record 34 of Set 14 | prata
# Processing Record 35 of Set 14 | englewood
# Processing Record 36 of Set 14 | atakpame
# Processing Record 37 of Set 14 | nacogdoches
# Processing Record 38 of Set 14 | morant bay
# Processing Record 39 of Set 14 | storsteinnes
# Processing Record 40 of Set 14 | hovd
# Processing Record 41 of Set 14 | enshi
# Processing Record 42 of Set 14 | moron
# Processing Record 43 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 14 | kutum
# Processing Record 45 of Set 14 | fostoria
# Processing Record 46 of Set 14 | shihezi
# Processing Record 47 of Set 14 | cayenne
# Processing Record 48 of Set 14 | temozon
# Processing Record 49 of Set 14 | gobabis
# Processing Record 50 of Set 14 | jelah
# Processing Record 1 of Set 15 | novaya mayna
# Processing Record 2 of Set 15 | rorvik
# Processing Record 3 of Set 15 | gao
# Processing Record 4 of Set 15 | kundiawa
# Processing Record 5 of Set 15 | zhigansk
# Processing Record 6 of Set 15 | bulgan
# Processing Record 7 of Set 15 | januaria
# Processing Record 8 of Set 15 | el faiyum
# City not found. Skipping...
# Processing Record 9 of Set 15 | la ronge
# Processing Record 10 of Set 15 | los llanos de aridane
# Processing Record 11 of Set 15 | timmins
# Processing Record 12 of Set 15 | ambilobe
# Processing Record 13 of Set 15 | roald
# Processing Record 14 of Set 15 | chipinge
# Processing Record 15 of Set 15 | port shepstone
# Processing Record 16 of Set 15 | arlit
# Processing Record 17 of Set 15 | nova olimpia
# Processing Record 18 of Set 15 | lensk
# Processing Record 19 of Set 15 | medina
# Processing Record 20 of Set 15 | fundao
# Processing Record 21 of Set 15 | baltimore
# Processing Record 22 of Set 15 | anori
# Processing Record 23 of Set 15 | kudat
# Processing Record 24 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 25 of Set 15 | takoradi
# Processing Record 26 of Set 15 | terrace bay
# Processing Record 27 of Set 15 | funadhoo
# Processing Record 28 of Set 15 | waingapu
# Processing Record 29 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 15 | santa cruz
# Processing Record 31 of Set 15 | panama city
# Processing Record 32 of Set 15 | wajima
# Processing Record 33 of Set 15 | konya
# Processing Record 34 of Set 15 | coruripe
# Processing Record 35 of Set 15 | takhli
# Processing Record 36 of Set 15 | malatya
# Processing Record 37 of Set 15 | villaviciosa
# Processing Record 38 of Set 15 | changli
# Processing Record 39 of Set 15 | darhan
# Processing Record 40 of Set 15 | huarmey
# Processing Record 41 of Set 15 | san francisco
# Processing Record 42 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 43 of Set 15 | tshane
# Processing Record 44 of Set 15 | quelimane
# Processing Record 45 of Set 15 | sampit
# Processing Record 46 of Set 15 | plainview
# Processing Record 47 of Set 15 | ajdabiya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
#city_data_df.head(10)

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0  Severo-Kurilsk      RU  2021-06-06 20:09:19  50.6789  156.1250     42.01
# 1       Cape Town      ZA  2021-06-06 20:05:03 -33.9258   18.4232     69.12
# 2     East London      ZA  2021-06-06 20:09:21 -33.0153   27.9116     63.30
# 3         Ushuaia      AR  2021-06-06 20:08:57 -54.8000  -68.3000     38.86
# 4          Salina      US  2021-06-06 20:09:25  38.8403  -97.6114     84.33
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        94         100        8.88     overcast clouds
# 1        25          20       10.22          few clouds
# 2        41           0        9.78           clear sky
# 3        87          40        9.22    scattered clouds
# 4        51          40       12.66    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
